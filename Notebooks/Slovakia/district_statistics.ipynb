# %% [markdown]
# # District information in Slovakia
# The aim of this notebook is to generate graphs for inter-district migration is Slovak districts

# %%
import os
import pandas as pd
import geopandas
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Markdown

# %% [markdown]
# ## Net migration map
# - Creates a map of districts and their population change

# %%
net_migration_raw = pd.read_csv("../../Data/slovakia/net_migration_districts_sk.csv")

districts_geodata = geopandas.read_file("../../Data/geography/slovak_districts.json")

# display(net_migration_raw.head())
# display(districts_geodata.head())

districts_net_migration = pd.merge(districts_geodata,net_migration_raw,on="LAU1_CODE")

display(districts_net_migration.head())
# Out:
#                LAU1                       DOW  IDN3               NM3  IDN2  \
# 0   Banská Bystrica 2021-02-26 00:00:00+00:00   601   Banská Bystrica     6
# 1  Banská Štiavnica 2021-02-26 00:00:00+00:00   602  Banská Štiavnica     6
# 2          Bardejov 2021-02-26 00:00:00+00:00   701          Bardejov     7
# 3      Bratislava I 2021-02-26 00:00:00+00:00   101      Bratislava I     1
# 4     Bratislava II 2021-02-26 00:00:00+00:00   102     Bratislava II     1
#
#                NM2               NUTS2 NUTS2_CODE                 NUTS3  \
# 0  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 1  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 2        Prešovský  Východné Slovensko       SK04        Prešovský kraj
# 3     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
# 4     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
#
#   NUTS3_CODE  ... 2003 2002 2001 2000  1999  1998  1997  1996  1995  1993
# 0      SK032  ... -109  -14   67    4    11  -166   -19   149   242     6
# 1      SK032  ...   10   39   26   15    46    97   100   -18    22    -7
# 2      SK041  ...  -93  -85  -79  -96   -63   -79   -52   -12   -47    75
# 3      SK010  ... -329 -238 -169  -43  -157  -240  -169   126   271    -3
# 4      SK010  ...  340  219  218  157  -150   -35    55   226   128   293
#
# [5 rows x 45 columns]

# %%
print(districts_net_migration.columns)
# Out:
# Index(['LAU1', 'DOW', 'IDN3', 'NM3', 'IDN2', 'NM2', 'NUTS2', 'NUTS2_CODE',
#        'NUTS3', 'NUTS3_CODE', 'LAU1_CODE', 'LAU2', 'LAU2_CODE', 'geometry',
#        '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016',
#        '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007',
#        '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998',
#        '1997', '1996', '1995', '1993'],
#       dtype='object')

# %% [markdown]
# #### Largest/smallest value in counties

# %%
def district_value_total(table,ascending = True):
    data = []
    
    for index,row in table.iterrows():
        name = row["NM3"]
        geography = row["geometry"]
        total = 0
        for year in range(1995,2024,1):
            total += row[str(year)]

        data.append({"District":name,
                     "geometry":geography,
                     "value":total})
    result_df = geopandas.GeoDataFrame(data)
    result_df.sort_values(by="value",ascending=ascending,inplace=True)
    # display(result_df.head())
    return result_df

# district_value_total(districts_net_migration,ascending=False)

# %% [markdown]
# #### Creating drawing function

# %%
from matplotlib.colors import Normalize, LinearSegmentedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable

def draw_districts(table, target_column, title_label="", colorbar_label="Value",fixed_max_value=None,fixed_min_value=None,filename="",color_scheme = ["red", "lightgray", "green"],biggest_text="Biggest net gain",smallest_text = "Biggest net loss"):
    fig, ax = plt.subplots(figsize=(8, 6))
    
    if fixed_max_value is None:
        max_value = max([abs(x) for x in table[target_column]])
        # print("Max value: ",max_value)
    else:
        max_value = fixed_max_value
    

    cmap = LinearSegmentedColormap.from_list("red_green", color_scheme)
    if fixed_min_value is None:
        min_value = -max_value
    elif fixed_min_value == "min":
        min_value = min([x for x in table[target_column]])
        # print(min_value)

    else:
        min_value = fixed_min_value
    
    norm = Normalize(vmin=min_value,vmax=max_value)

    # axes = table.plot(column = target_column,legend=True,cmap=cmap,norm=norm,edgecolor="gray",linewidth=0.3)

    table.plot(
        column=target_column,
        cmap=cmap,
        norm=norm,
        edgecolor="gray",
        linewidth=0.3,
        ax=ax,
        legend=False
    )

    # I used ChatGPT to write this paragraph of code
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="3%", pad=0.1)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm._A = []
    cbar = plt.colorbar(sm, cax=cax)
    cbar.ax.tick_params(labelsize=8)
    cbar.set_label(colorbar_label, fontsize=10)


    ax.set_title(title_label, fontsize=18,  pad=15)
    ax.set_axis_off()
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    #Net gain and loss
    gain_table = table.sort_values(str(target_column),ascending=False).head()
    
    loss_table = table.sort_values(str(target_column),ascending=True).head()

    #constant, change here:
    n_districts = 5
    gain = []
    loss = []
    
    for i in range(n_districts):
        gain.append((gain_table.iloc[i,0],float(gain_table.iloc[i,:][str(target_column)])))
        loss.append((loss_table.iloc[i,0],float(loss_table.iloc[i,:][str(target_column)])))
    
    gain_text = rf"$\bf { "\\ ".join(biggest_text.split())}$"+"\n"

    for district,value in gain:
        gain_text += district + ": "+ f"{value:.1f}" + "\n"
    
    loss_text = rf"$\bf {"\\ ".join(smallest_text.split())}$"+"\n"
    for district,value in loss:
        loss_text += district + ": "+ f"{value:.1f}" + "\n"

    plt.figtext(0.4, 0.1, gain_text, ha='left', fontsize=9, wrap=False)
    plt.figtext(0.6, 0.1, loss_text, ha='left', fontsize=9, wrap=False)

    plt.tight_layout()
    if filename != "":
        # os.makedirs("../../Images/Slovakia",exist_ok=True)
        plt.savefig("../../Images/Slovakia/"+filename+".png")
        plt.close()
    else:
        plt.show()

# draw_districts(districts_net_migration, str(2020), title_label="District migration in "+str(2020), colorbar_label="Total migration change",filename="")

# %% [markdown]
# #### Drawing multiple maps

# %%
# for year in range(1995,2024,1):
#     draw_districts(districts_net_migration, str(year), title_label="District migration in "+str(year), colorbar_label="Total migration change",fixed_max_value=None,filename="Migration/Relative/district_migration_change_"+str(year))

# for year in range(1995,2024,1):
#     draw_districts(districts_net_migration, str(year), title_label="District migration in "+str(year), colorbar_label="Total migration change",fixed_max_value=3000,filename="Migration/Uniform/uniform_district_migration_change_"+str(year))

# draw_districts(districts_net_migration, str(1993), title_label="District migration in "+str(1993), colorbar_label="Total migration change",fixed_max_value=None,filename="Migration/Relative/district_migration_change_"+str(1993))
# draw_districts(districts_net_migration, str(1993), title_label="District migration in "+str(1993), colorbar_label="Total migration change",fixed_max_value=3000,filename="Migration/Uniform/uniform_district_migration_change_"+str(1993))


# draw_districts(districts_net_migration, str(2020), title_label="District migration in "+str(2020), colorbar_label="Total migration change",filename="")

# %% [markdown]
# #### Drawing total change

# %%
#Total change
total_table = district_value_total(districts_net_migration,True)
display(total_table.head())
# draw_districts(total_table,target_column="value",title_label="Total district migration from 1995 to 2023",colorbar_label="Total migration change",filename="total_district_change")
# Out:
#             District                                           geometry  value
# 7       Bratislava V  POLYGON ((-568838.92 -1291406.77, -568471.28 -... -17699
# 24        Košice III  POLYGON ((-257734.5 -1238885.75, -257766 -1238...  -7257
# 23         Košice II  POLYGON ((-266711.3 -1248792.99, -265963.61 -1...  -7187
# 60  Spišská Nová Ves  POLYGON ((-313920.46 -1226105.61, -313841.21 -...  -5400
# 17           Humenné  POLYGON ((-209754.12 -1227503.03, -209734.27 -...  -5350

# %% [markdown]
# ### Most immigration/emigration districts

# %%
display(Markdown("### Districts with biggest net gain in 2023"))
display(districts_net_migration.sort_values("2023",ascending=False).head(10))

display(Markdown("### Districts with biggest net loss in 2023"))
display(districts_net_migration.sort_values("2023",ascending=True).head(10))
# Out:
# ### Districts with biggest net gain in 2023
#                LAU1                       DOW  IDN3              NM3  IDN2  \
# 55            Senec 2021-02-26 00:00:00+00:00   108            Senec     1
# 13  Dunajská Streda 2021-02-26 00:00:00+00:00   201  Dunajská Streda     2
# 21  Košice - okolie 2021-02-26 00:00:00+00:00   806  Košice - okolie     8
# 5    Bratislava III 2021-02-26 00:00:00+00:00   103   Bratislava III     1
# 3      Bratislava I 2021-02-26 00:00:00+00:00   101     Bratislava I     1
# 4     Bratislava II 2021-02-26 00:00:00+00:00   102    Bratislava II     1
# 32          Malacky 2021-02-26 00:00:00+00:00   106          Malacky     1
# 14          Galanta 2021-02-26 00:00:00+00:00   202          Galanta     2
# 67           Trnava 2021-02-26 00:00:00+00:00   207           Trnava     2
# 37            Nitra 2021-02-26 00:00:00+00:00   403            Nitra     4
#
#              NM2               NUTS2 NUTS2_CODE              NUTS3 NUTS3_CODE  \
# 55  Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj      SK010
# 13      Trnavský   Západné Slovensko       SK02      Trnavský kraj      SK021
# 21       Košický  Východné Slovensko       SK04       Košický kraj      SK042
# 5   Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj      SK010
# 3   Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj      SK010
# 4   Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj      SK010
# 32  Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj      SK010
# 14      Trnavský   Západné Slovensko       SK02      Trnavský kraj      SK021
# 67      Trnavský   Západné Slovensko       SK02      Trnavský kraj      SK021
# 37    Nitriansky   Západné Slovensko       SK02    Nitriansky kraj      SK023
#
#     ... 2003  2002 2001 2000  1999  1998  1997  1996  1995  1993
# 55  ...  789  1002  550  576   268   283   183   125   -32    35
# 13  ...  770   498  300  169   253   377   261   146    88    53
# 21  ...  600   660  412  304   287   513   333   538   -31    25
# 5   ...  127   400  519  140   100  -159   177   214   115   201
# 3   ... -329  -238 -169  -43  -157  -240  -169   126   271    -3
# 4   ...  340   219  218  157  -150   -35    55   226   128   293
# 32  ...  552   527  350  361   307   416   391   262   204    41
# 14  ...  497   171  193  303   256   330   409   208   101    32
# 67  ...  146   -23  111   38   258   145   -54    61    89   -93
# 37  ...  198   176  181  113   247   236   162   190    99    95
#
# [10 rows x 45 columns]
# ### Districts with biggest net loss in 2023
#                  LAU1                       DOW  IDN3                NM3  \
# 23          Košice II 2021-02-26 00:00:00+00:00   803          Košice II
# 71  Vranov nad Topľou 2021-02-26 00:00:00+00:00   713  Vranov nad Topľou
# 22           Košice I 2021-02-26 00:00:00+00:00   802           Košice I
# 60   Spišská Nová Ves 2021-02-26 00:00:00+00:00   810   Spišská Nová Ves
# 7        Bratislava V 2021-02-26 00:00:00+00:00   105       Bratislava V
# 48          Prievidza 2021-02-26 00:00:00+00:00   307          Prievidza
# 2            Bardejov 2021-02-26 00:00:00+00:00   701           Bardejov
# 39         Nové Zámky 2021-02-26 00:00:00+00:00   404         Nové Zámky
# 45             Poprad 2021-02-26 00:00:00+00:00   706             Poprad
# 46  Považská Bystrica 2021-02-26 00:00:00+00:00   306  Považská Bystrica
#
#     IDN2           NM2               NUTS2 NUTS2_CODE              NUTS3  \
# 23     8       Košický  Východné Slovensko       SK04       Košický kraj
# 71     7     Prešovský  Východné Slovensko       SK04     Prešovský kraj
# 22     8       Košický  Východné Slovensko       SK04       Košický kraj
# 60     8       Košický  Východné Slovensko       SK04       Košický kraj
# 7      1  Bratislavský   Bratislavský kraj       SK01  Bratislavský kraj
# 48     3   Trenčiansky   Západné Slovensko       SK02   Trenčiansky kraj
# 2      7     Prešovský  Východné Slovensko       SK04     Prešovský kraj
# 39     4    Nitriansky   Západné Slovensko       SK02    Nitriansky kraj
# 45     7     Prešovský  Východné Slovensko       SK04     Prešovský kraj
# 46     3   Trenčiansky   Západné Slovensko       SK02   Trenčiansky kraj
#
#    NUTS3_CODE  ... 2003 2002 2001 2000  1999  1998  1997  1996  1995  1993
# 23      SK042  ... -383 -502  -12  -53   135  -308  -728  -518  -158  -322
# 71      SK041  ...  -84 -127 -114  -27    44   -31    59   -18   -34   -17
# 22      SK042  ...   20    0   50  105    49   -14  1052   873   541   114
# 60      SK042  ... -156  -45  -46    6  -138   -91   -51   -28    13   -88
# 7       SK010  ... -976 -847 -663 -523  -470  -757  -593  -701  -565 -1097
# 48      SK022  ... -118 -205 -216 -176  -163  -154    -8  -106   -64   -14
# 2       SK041  ...  -93  -85  -79  -96   -63   -79   -52   -12   -47    75
# 39      SK023  ...  139   19  -57  202   154   201   127    70    11    -8
# 45      SK041  ... -360 -294 -104 -147  -117  -214   -99    33   -44    -9
# 46      SK022  ... -107    5 -100  -44   -75   -39    30   -31    21   151
#
# [10 rows x 45 columns]

# %% [markdown]
# ## Unemployment

# %% [markdown]
# #### Creating table

# %%
unemployment_migration_raw = pd.read_csv("../../Data/slovakia/unemployment_districts_sk.csv")

districts_unemployment = pd.merge(districts_geodata,unemployment_migration_raw,on="LAU1_CODE")

display(districts_unemployment.head())
# Out:
#                LAU1                       DOW  IDN3               NM3  IDN2  \
# 0   Banská Bystrica 2021-02-26 00:00:00+00:00   601   Banská Bystrica     6
# 1  Banská Štiavnica 2021-02-26 00:00:00+00:00   602  Banská Štiavnica     6
# 2          Bardejov 2021-02-26 00:00:00+00:00   701          Bardejov     7
# 3      Bratislava I 2021-02-26 00:00:00+00:00   101      Bratislava I     1
# 4     Bratislava II 2021-02-26 00:00:00+00:00   102     Bratislava II     1
#
#                NM2               NUTS2 NUTS2_CODE                 NUTS3  \
# 0  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 1  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 2        Prešovský  Východné Slovensko       SK04        Prešovský kraj
# 3     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
# 4     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
#
#   NUTS3_CODE  ...   2009   2008   2007   2006   2005   2004   2003   2002  \
# 0      SK032  ...   8.43   4.40   4.33   5.54   7.40   8.68  10.72  10.55
# 1      SK032  ...  16.92  14.89  13.36  15.43  18.18  17.33  19.98  19.93
# 2      SK041  ...  22.00  15.75  13.01  14.05  15.96  17.38  19.98  24.05
# 3      SK010  ...   2.71   1.46   1.56   1.77   2.04   2.58   3.67   4.85
# 4      SK010  ...   4.00   1.87   1.56   1.85   2.07   2.87   2.96   3.62
#
#    2 001.00   2001
# 0     11.44  11.44
# 1     20.37  20.37
# 2     23.40  23.40
# 3      6.15   6.15
# 4      3.79   3.79
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Drawing multiple maps

# %%
# for year in range(2001,2023,1):
#     draw_districts(districts_unemployment, str(year), title_label="Unemployment in "+str(year), 
#                    colorbar_label="Unemployment (%)",filename="/Economy/Relative/district_unemployment_"+str(year)+".png",fixed_min_value=0,color_scheme=["white","red"],
#                    biggest_text="Largest percentage",
#                    smallest_text="Smallest percentage")
# for year in range(2001,2023,1):
#     draw_districts(districts_unemployment, str(year), title_label="Unemployment in "+str(year), 
#                    colorbar_label="Unemployment (%)",filename="/Economy/Uniform/uniform_district_unemployment_"+str(year)+".png",fixed_min_value=0,color_scheme=["white","red"],
#                    biggest_text="Largest percentage",
#                    smallest_text="Smallest percentage",fixed_max_value=35)
#     draw_districts(districts_unemployment, str(year), title_label="Unemployment in "+str(year), 
#                    colorbar_label="Unemployment (%)",fixed_min_value=0,color_scheme=["white","red"],
#                    biggest_text="Largest percentage",
#                    smallest_text="Smallest percentage",fixed_max_value=35,filename="")
    
draw_districts(districts_unemployment, str(2020), title_label="Unemployment in "+str(2020), 
                   colorbar_label="Unemployment (%)",fixed_min_value=0,color_scheme=["white","red"],
                   biggest_text="Largest percentage",
                   smallest_text="Smallest percentage",fixed_max_value=35)

# %% [markdown]
# ## Average montly salary

# %%
monthly_salary_raw = pd.read_csv("../../Data/slovakia/average_montly_salary_districts_sk.csv")

districts_salary = pd.merge(districts_geodata,monthly_salary_raw,on="LAU1_CODE")

display(districts_salary.head())
# Out:
#                LAU1                       DOW  IDN3               NM3  IDN2  \
# 0   Banská Bystrica 2021-02-26 00:00:00+00:00   601   Banská Bystrica     6
# 1  Banská Štiavnica 2021-02-26 00:00:00+00:00   602  Banská Štiavnica     6
# 2          Bardejov 2021-02-26 00:00:00+00:00   701          Bardejov     7
# 3      Bratislava I 2021-02-26 00:00:00+00:00   101      Bratislava I     1
# 4     Bratislava II 2021-02-26 00:00:00+00:00   102     Bratislava II     1
#
#                NM2               NUTS2 NUTS2_CODE                 NUTS3  \
# 0  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 1  Banskobystrický   Stredné Slovensko       SK03  Banskobystrický kraj
# 2        Prešovský  Východné Slovensko       SK04        Prešovský kraj
# 3     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
# 4     Bratislavský   Bratislavský kraj       SK01     Bratislavský kraj
#
#   NUTS3_CODE  ...  2018  2017  2016  2015  2014  2013  2012  2011  2010  \
# 0      SK032  ...  1126  1075   999   957   941   867   868   831   781
# 1      SK032  ...   878   690   725   732   714   678   790   792   621
# 2      SK041  ...   726   716   658   636   614   597   604   580   492
# 3      SK010  ...  1553  1495  1486  1375  1334  1237  1247  1211  1275
# 4      SK010  ...  1696  1499  1392  1446  1422  1316  1260  1224  1327
#
#       2009
# 0   755.67
# 1   621.10
# 2   465.56
# 3  1293.02
# 4  1355.76
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Drawing multiple maps

# %%
for year in range(2009,2024,1):
    #relative
    draw_districts(districts_salary, str(year), title_label="Average monthly nominal salary in "+str(year), 
                   colorbar_label="Monthly salary (€)",filename="/Salary/Relative/district_salary_"+str(year)+".png",fixed_min_value="min",color_scheme=["white","gold","olive"],
                   biggest_text="Highest salary",
                   smallest_text="Lowest salary")
    #uniform
    draw_districts(districts_salary, str(year), title_label="Average monthly nominal salary in "+str(year), 
                   colorbar_label="Monthly salary (€)",filename="/Salary/Uniform/district_salary_"+str(year)+".png",fixed_min_value=450,fixed_max_value=2250,color_scheme=["white","gold","olive"],
                   biggest_text="Highest salary",
                   smallest_text="Lowest salary")
    

draw_districts(districts_salary, str(2020), title_label="Average monthly nominal salary in "+str(2020), 
                   colorbar_label="Monthly salary (€)",fixed_min_value=900,color_scheme=["white","gold","olive"],
                   biggest_text="Highest salary",
                   smallest_text="Lowest salary")
# Out:
# 465.56
# 492
# 580
# 604
# 597
# 614
# 636
# 658
# 690
# 726
# 853
# 895
# 983
# 1021
# 1161
